# %%
import pandas as pd
from transformers import GPT2Tokenizer
from transformers import GPT2LMHeadModel
import torch

# %%
df = pd.read_csv('data/filter_data.csv')
# Inicializar el tokenizador de GPT-2
tokenizer = GPT2Tokenizer.from_pretrained('gpt2_spa_local')  # O la ruta a tu modelo si ya lo descargaste
# Crear una lista para almacenar los datos preparados
prepared_data = []

# Iterar sobre cada fila del DataFrame
for index, row in df.iterrows():
    # Concatenar letras con sentimientos
    input_text = f"{row['lyrics']} [SENTIMENTS] {row['feelings']}"
    prepared_data.append(input_text)
# Tokenizar los datos
tokenized_data = [tokenizer.encode(text, return_tensors='pt') for text in prepared_data]
# Cargar el modelo
model = GPT2LMHeadModel.from_pretrained('./gpt2_spa_local')
model.train()  # Establecer el modelo en modo de entrenamiento

# Mover el modelo a la GPU (si está disponible)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)

# %%
from torch.optim import AdamW

# Configuración del optimizador
optimizer = AdamW(model.parameters(), lr=5e-5)

# Número de épocas
num_epochs = 3  # Ajusta según sea necesario

for epoch in range(num_epochs):
    for tokenized_input in tokenized_data:
        # Mover datos a la GPU
        tokenized_input = tokenized_input.to(device)

        # Adelante (Forward)
        outputs = model(tokenized_input, labels=tokenized_input)
        loss = outputs.loss

        # Retropropagación (Backward)
        loss.backward()

        # Actualizar los pesos
        optimizer.step()
        optimizer.zero_grad()

        print(f"Epoch: {epoch}, Loss: {loss.item()}")
# Out:
# Epoch: 0, Loss: 6.125394821166992
# Epoch: 0, Loss: 4.521975517272949
# Epoch: 0, Loss: 6.078360080718994
# Epoch: 0, Loss: 5.354247093200684
# Epoch: 0, Loss: 7.365292549133301
# Epoch: 0, Loss: 6.2282328605651855
# Epoch: 0, Loss: 6.046369552612305
# Epoch: 0, Loss: 5.607619762420654
# Epoch: 0, Loss: 4.170190334320068
# Epoch: 0, Loss: 5.716723442077637
# Epoch: 0, Loss: 7.027527332305908
# Epoch: 0, Loss: 6.694766998291016
# Epoch: 0, Loss: 5.275996685028076
# Epoch: 0, Loss: 4.747635364532471
# Epoch: 0, Loss: 4.751110553741455
# Epoch: 0, Loss: 4.4834885597229
# Epoch: 0, Loss: 5.4618821144104
# Epoch: 0, Loss: 5.167383670806885
# Epoch: 0, Loss: 4.726057052612305
# Epoch: 0, Loss: 4.949235916137695
# Epoch: 0, Loss: 3.388848066329956
# Epoch: 0, Loss: 5.1946516036987305
# Epoch: 0, Loss: 4.779718399047852
# Epoch: 0, Loss: 3.6908445358276367
# Epoch: 0, Loss: 4.80611515045166
# Epoch: 0, Loss: 4.464014053344727
# Epoch: 0, Loss: 3.011209011077881
# Epoch: 0, Loss: 4.578606128692627
# Epoch: 0, Loss: 4.513789176940918
# Epoch: 0, Loss: 4.367135524749756
# Epoch: 0, Loss: 3.815688133239746
# Epoch: 0, Loss: 2.5091493129730225
# Epoch: 0, Loss: 3.739225387573242
# Epoch: 0, Loss: 3.4203689098358154
# Epoch: 0, Loss: 5.317623615264893
# Epoch: 0, Loss: 5.555297374725342
# Epoch: 0, Loss: 3.5733535289764404
# Epoch: 0, Loss: 5.0302348136901855
# Epoch: 0, Loss: 4.756387710571289
# Epoch: 0, Loss: 3.7085204124450684
# Epoch: 0, Loss: 5.071709156036377
# Epoch: 0, Loss: 4.0466718673706055
# Epoch: 0, Loss: 4.664056777954102
# Epoch: 0, Loss: 4.392446041107178
# Epoch: 0, Loss: 4.12089729309082
# Epoch: 0, Loss: 3.9418838024139404
# Epoch: 0, Loss: 4.176833152770996
# Epoch: 0, Loss: 4.945749759674072
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 15
#      12 tokenized_input = tokenized_input.to(device)
#      14 # Adelante (Forward)
# ---> 15 outputs = model(tokenized_input, labels=tokenized_input)
#      16 loss = outputs.loss
#      18 # Retropropagación (Backward)
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\transformers\models\gpt2\modeling_gpt2.py:1316, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1308 r"""
#    1309 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1310     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#    1311     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#    1312     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1313 """
#    1314 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1316 transformer_outputs = self.transformer(
#    1317     input_ids,
#    1318     past_key_values=past_key_values,
#    1319     attention_mask=attention_mask,
#    1320     token_type_ids=token_type_ids,
#    1321     position_ids=position_ids,
#    1322     head_mask=head_mask,
#    1323     inputs_embeds=inputs_embeds,
#    1324     encoder_hidden_states=encoder_hidden_states,
#    1325     encoder_attention_mask=encoder_attention_mask,
#    1326     use_cache=use_cache,
#    1327     output_attentions=output_attentions,
#    1328     output_hidden_states=output_hidden_states,
#    1329     return_dict=return_dict,
#    1330 )
#    1331 hidden_states = transformer_outputs[0]
#    1333 # Set device for model parallelism
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\transformers\models\gpt2\modeling_gpt2.py:1130, in GPT2Model.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#    1118     outputs = self._gradient_checkpointing_func(
#    1119         block.__call__,
#    1120         hidden_states,
#    (...)
#    1127         output_attentions,
#    1128     )
#    1129 else:
# -> 1130     outputs = block(
#    1131         hidden_states,
#    1132         layer_past=layer_past,
#    1133         attention_mask=attention_mask,
#    1134         head_mask=head_mask[i],
#    1135         encoder_hidden_states=encoder_hidden_states,
#    1136         encoder_attention_mask=encoder_attention_mask,
#    1137         use_cache=use_cache,
#    1138         output_attentions=output_attentions,
#    1139     )
#    1141 hidden_states = outputs[0]
#    1142 if use_cache is True:
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\transformers\models\gpt2\modeling_gpt2.py:652, in GPT2Block.forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     650 residual = hidden_states
#     651 hidden_states = self.ln_2(hidden_states)
# --> 652 feed_forward_hidden_states = self.mlp(hidden_states)
#     653 # residual connection
#     654 hidden_states = residual + feed_forward_hidden_states
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\transformers\models\gpt2\modeling_gpt2.py:575, in GPT2MLP.forward(self, hidden_states)
#     574 def forward(self, hidden_states: Optional[Tuple[torch.FloatTensor]]) -> torch.FloatTensor:
# --> 575     hidden_states = self.c_fc(hidden_states)
#     576     hidden_states = self.act(hidden_states)
#     577     hidden_states = self.c_proj(hidden_states)
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File g:\Melody-Lyric-Generator-from-Sheet-Music\.venv\Lib\site-packages\transformers\pytorch_utils.py:111, in Conv1D.forward(self, x)
#     109 def forward(self, x):
#     110     size_out = x.size()[:-1] + (self.nf,)
# --> 111     x = torch.addmm(self.bias, x.view(-1, x.size(-1)), self.weight)
#     112     x = x.view(size_out)
#     113     return x
#
# KeyboardInterrupt:

# %%
model.save_pretrained('./trained_gpt2_spa_local')
tokenizer.save_pretrained('./trained_gpt2_spa_local')
