# %%
import tensorflow as tf # type: ignore
import tensorflow_datasets as tfds # type: ignore

# Cargar el dataset MAESTRO v3
dataset, info = tfds.load('maestro', with_info=True, as_supervised=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import tensorflow as tf # type: ignore
#       2 import tensorflow_datasets as tfds # type: ignore
#       4 # Cargar el dataset MAESTRO v3
#
# ModuleNotFoundError: No module named 'tensorflow'
